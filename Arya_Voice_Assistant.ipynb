# %%
# %pip install nltk
# %pip install SpeechRecognition
# %pip install google-api-python-client
# %pip install PyAudio
# Out:
# Requirement already satisfied: nltk in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (3.10.2)
# Requirement already satisfied: defusedxml in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from nltk) (8.4.2)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from nltk) (2026.7.19)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from nltk) (4.70.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: SpeechRecognition in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (3.17.0)
# Requirement already satisfied: typing-extensions in /Users/martins/Library/Python/3.14/lib/python/site-packages (from SpeechRecognition) (4.15.0)
# Requirement already satisfied: standard-aifc in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from SpeechRecognition) (3.13.0)
# Requirement already satisfied: audioop-lts in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from SpeechRecognition) (0.2.2)
# Requirement already satisfied: standard-chunk in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from standard-aifc->SpeechRecognition) (3.13.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-api-python-client in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (2.198.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-api-python-client) (0.32.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-api-python-client) (2.56.3)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-api-python-client) (0.4.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-api-python-client) (2.34.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.69.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.75.1)
# Requirement already satisfied: protobuf<8.0.0,>=6.33.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (7.35.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.26.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.28.3)
# Requirement already satisfied: requests<3.0.0,>=2.33.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.34.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: cryptography>=41.0.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (50.0.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2026.7.22)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from cryptography>=41.0.5->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (2.1.1)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=41.0.5->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: PyAudio in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (0.2.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
from nltk import wordpunct_tokenize
import pyaudio
import speech_recognition as srec
import datetime
import random
print("Import finished!")
# Out:
# Import finished!

# %%
# Creating an object
recording = srec.Recognizer()

# Using the computer's microphone as the source of audio
with srec.Microphone() as source:
    print("Arya is listening...")
    audio = recording.listen(source, timeout=5)

print("Audio received!")
# Out:
# Arya is listening...
# Audio received!

# %%
try: 
    command = recording.recognize_google(audio)
    command = command.lower()
    print("You said:", command)

except:
    print("Sorry I didn't understand what you said.")
# Out:
# You said: hi how are you

# %%
# Tokenizing the user's command
tokens = wordpunct_tokenize(command)
print("Tokens:", tokens)
# Out:
# Tokens: ['hi', 'how', 'are', 'you']

# %%
# Checking what the user wants Arya to do
if "hello"  in command or "hi" in command or "hey" in command:
    print("Hello! I'm Arya, how can I help you today?")

elif "what is your name" in command:
    print("My name is Arya, and you?")

elif "my name is" in command:
    name = command.replace("my name is", "").strip()
    print("Nice to meet you,", name.title())

elif "how are you" in command:
    print("I am doing very well, and you?")

elif "what time is it" in command or "what is the time" in command:
    current_time = datetime.datetime.now().strftime("%I:%M %p")
    print("The current time is", current_time)

elif "what is today's date" in command or "what is the date" in command:
    current_date = datetime.datetime.now().strftime("%B %d, %Y")
    print("Today's date is", current_date)

elif "what day is it" in command or "what day of the week is it" in command:
    current_day = datetime.datetime.now().strftime("%A")
    print("Today is", current_day)

else:
    print("I'm not sure how to respond to that.")
# Out:
# I'm not sure how to respond to that.

# %% [markdown]
# ### Development Notes and Debugging
# | **Issue** | **Error** | **Cause** | **Solution** |
# |---|---|---|---|
# | PyAudio could not install successfully. | `fatal error: 'portaudio.h' file not found` | To access the computer's microphone, PyAudio needs PortAudio. | I will install PortAudio, then attempt to install PyAudio again. |
